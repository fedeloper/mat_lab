# %% [markdown]
# # Readme: how to handle our Sentinel-1 ASC-DESC dataset
#
# ###What you have:
# A list of big geotiff file (.tif) Pairs. Each image in the pair should roughly correspond to the same area as the other. Each geotiff can by read using rasterio or gdal, as you can see in the notebook.
#
# ###What you should do:
# create single datapoints to train/test your models.
#
# ###How to do it:
# For each big pair, get a datapoint by cropping a random patch from one side (this acts as the "query" patch, the one you want to look for) and cropping a patch around the same coordinates from the other side (this acts as the "search" patch, the one to want to search in). Add distortions: search patch has to be taken with a random offset around query patch (perhaps random but normally distributed around offset 0, which means query patch at the centre). Also add a bit of random scale and rotation.Try finding a 1km^2 query patch inside a 4km^2 search patch.
#
# ###Some WARNINGS (not too sure about them)
#
# Warning: do not include every correspondence in the ground truth pixel correspondence list! you should only insert meaningful correspondences such as harris corners.
#
# Warning: maybe discard a candidate query altogether if it's not feature-rich enough. You can do this using pixel histograms (has to have more than n peaks -> use scikit learn), or maybe entropy. for example, if every pixel is around e.g. 150, this means that everything is gray and unmatchable.

# %%
from scipy.ndimage import uniform_filter, variance
from skimage.transform import AffineTransform


import PIL
from PIL import Image, ImageFilter

import rasterio as rio
from rasterio import warp

import matplotlib

from matplotlib import pyplot as plt

import argparse


import pytorch_lightning as pl



import pandas as pd

# Need this to plot in HD
# This takes up a lot of memory!
matplotlib.rcParams['figure.dpi'] = 300

if 'model_TransSAR' not in locals():
    model_TransSAR=None
# Out:
# 2023-02-27 12:30:29.392632: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-27 12:30:30.361770: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-02-27 12:30:30.361928: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-02-27 12:30:30.361934: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Requirement already satisfied: rasterio in /home/fred/anaconda3/envs/pythonProject/lib/python3.10/site-packages (1.3.5.post1)
# Requirement already satisfied: certifi in /home/fred/anaconda3/envs/pythonProject/lib/python3.10/site-packages (from rasterio) (2022.12.7)
# Requirement already satisfied: snuggs>=1.4.1 in /home/fred/anaconda3/envs/pythonProject/lib/python3.10/site-packages (from rasterio) (1.4.7)
# Requirement already satisfied: click-plugins in /home/fred/anaconda3/envs/pythonProject/lib/python3.10/site-packages (from rasterio) (1.1.1)
# Requirement already satisfied: click>=4.0 in /home/fred/anaconda3/envs/pythonProject/lib/python3.10/site-packages (from rasterio) (8.1.3)
# Requirement already satisfied: cligj>=0.5 in /home/fred/anaconda3/envs/pythonProject/lib/python3.10/site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=1.18 in /home/fred/anaconda3/envs/pythonProject/lib/python3.10/site-packages (from rasterio) (1.23.4)
# Requirement already satisfied: attrs in /home/fred/anaconda3/envs/pythonProject/lib/python3.10/site-packages (from rasterio) (22.2.0)
# Requirement already satisfied: setuptools in /home/fred/anaconda3/envs/pythonProject/lib/python3.10/site-packages (from rasterio) (65.6.3)
# Requirement already satisfied: affine in /home/fred/anaconda3/envs/pythonProject/lib/python3.10/site-packages (from rasterio) (2.4.0)
# Requirement already satisfied: pyparsing>=2.1.6 in /home/fred/anaconda3/envs/pythonProject/lib/python3.10/site-packages (from snuggs>=1.4.1->rasterio) (3.0.9)

# %%
def get_correspondence_multi(src_data, dst_data, src_row, src_col):
  ''' Gets the pixel coordinates (dst_row,dst_col) in dst_data of a given pixel at (src_row,src_col) in src_data.
      Warning: no handling of pixel being outside dst_data! You have to handle that yourself.
      TODO: Should add a check to only get the correspondences with high enough cornerness on both sides
      (because we should only insert meaningful correspondences in the list!).
  '''
  # Get geo coords of pixel from src dataset
  X1, Y1 = rio.transform.xy(src_data.transform, src_row, src_col)
  # print("Geographic coordinates in crs 1: ",X1,Y1)

  if src_data.crs != dst_data.crs:
    # convert coordinates in the crs of the dst dataset
    X2, Y2 = warp.transform(src_data.crs, dst_data.crs, X1, Y1)
  else:
    # if the crs is the same, do nothing
    X2, Y2 = X1, Y1

  # Get corresponding px coords in dst dataset
  # It still returns an index even if out of bounds
  dst_row, dst_col = rio.transform.rowcol(dst_data.transform, X2, Y2)
  # print("Corresponding pixel coordinates in image 2: ",dst_row,dst_col)
  return dst_row, dst_col

def get_correspondence(src_data, dst_data ,src_row, src_col):
  ''' Gets the pixel coordinates (dst_row,dst_col) in dst_data of a given pixel at (src_row,src_col) in src_data.
      Warning: no handling of pixel being outside dst_data! You have to handle that yourself.
      TODO: Should add a check to only get the correspondences with high enough cornerness on both sides 
      (because we should only insert meaningful correspondences in the list!).
  '''
  # Get geo coords of pixel from src dataset
  X1, Y1 = src_data.xy(src_row, src_col)
  X1,Y1 = X1 if type(X1) is list else [X1], Y1 if type(Y1) is list else [Y1]
  #print("Geographic coordinates in crs 1: ",X1,Y1)

  if src_data.crs != dst_data.crs:
    # convert coordinates in the crs of the dst dataset
    X2, Y2 = warp.transform(src_data.crs, dst_data.crs,X1,Y1)
    X2 = X2[0]
    Y2 = Y2[0]
  else: 
    # if the crs is the same, do nothing
    X2, Y2 = X1, Y1

  # Get corresponding px coords in dst dataset
  # It still returns an index even if out of bounds
  dst_row, dst_col = dst_data.index(X2, Y2)
  dst_row, dst_col =  dst_row[0] if type(dst_row) is list else dst_row, dst_col[0] if type(dst_col) is list else dst_col
  if dst_row < 0 or dst_col <0:
      print("make the margin higher, the corresponding points are outside the image")
  #print("Corresponding pixel coordinates in image 2: ",dst_row,dst_col)
  return dst_row , dst_col

def get_datapoint(ref_data,query_data):
  ''' TODO: Call this method on a pair of rasterio datasets. It will generate a random datapoint consisting
      of a smaller SAR patch from the query dataset, and a bigger SAR patch from the reference dataset. 
      The search patch contains the area of the smaller patch, with a random offset. 
  '''
  datapoint = None
  return datapoint

def is_good_patch(patch):
  ''' TODO: Checks if the random query patch is sufficiently texture-rich to be used to train/test the matching model.
      If the patch is too plain (e.g. sea or desert), returns False. This function should also be used at test time: 
      if a sensor image is too plain, there's no need to match it. 
      At test time, something similar should also be done on the reference side. 
  '''
  good = None
  return good

def get_keypoints(patch):
  ''' TODO: Use something like harris corner detection to get the list of ground truth correspondences.
      In fact, you should not train on each pixel corresp, but you should select only meaningful corresp!
      Harris peaks might be just strong speckle noise, but if you take strong ones you should be fine.
  '''
  keypoints = None
  return keypoints

def normalize_image(img):
  ''' Normalize by clipping to 99th percentile and convert to uint8.
      This clips strong speckle outliers and optimizes the brightness range
  '''
  p1 = np.nanpercentile(img,99)
  img = img.clip(0,p1)
  img = (img-np.nanmin(img))/(np.nanmax(img)-np.nanmin(img))*255
  img = img.astype(np.uint8, copy=True)
  return img

# %%
paths = ['./data/paired_sentinel/Sentinel1-AD Dataset- Lat-0.015502064951149919Lon41.3552557262833/S1A_IW_GRDH_1SDV_20220808T060138_20220808T060203_044457_054E18_B16D.tif',
         './data/paired_sentinel/Sentinel1-AD Dataset- Lat-0.015502064951149919Lon41.3552557262833/S1A_IW_GRDH_1SDV_20220814T175523_20220814T175548_044552_055140_2AEA.tif']


import random
def get_sample(tiff1_path,tiff2_path,search_window,patch_size,margin=40,random_seed=1,verbose=True,random_rotation=0.03,random_zoom=0.03):
  '''
        1-Reads the first band of the TIFF files using the rio library and normalizes the image data.
        2-Selects a random search window and patch location within the image using random number generators.
        3-Calls the get_correspondence function on the selected locations to find the corresponding locations in the second image.
        4-Converts the grayscale images to RGB format using OpenCV.
        5-Creates centered patches from the RGB images by zero-padding the images and copying a portion of the original images to the patches.
        6-Draws rectangles around the search window and patch in both images.
        7-Saves the patch and search window as JPEG files.
        8-Returns the processed RGB images, the points of the search window and patch, and the original rio datasets.

  '''
  dataset1 = rio.open(tiff1_path)
  dataset2 = rio.open(tiff2_path)
  img1 = dataset1.read(1)
  img1 = normalize_image(img1)
  img2 = dataset2.read(1)
  img2 = normalize_image(img2)

  img1= np.swapaxes(img1,0,1)
  img2= np.swapaxes(img2,0,1)

  search_window_w,search_window_h = search_window
  patch_size_w,patch_size_h = patch_size

  if img1.shape[0]-search_window_w-margin*2 <0  or img1.shape[1]-search_window_h-margin*2 <0:
    print("margin + search windows is too big for the image:",margin,"*2 +",(search_window_w,search_window_h),">",img1.shape)
    return None,None,None,None,None,None,None
  lu = ( margin+random.randint(0,img1.shape[0]-search_window_w-margin*2),margin+random.randint(0,img1.shape[1]-search_window_h-margin*2))
  lu_patch=( lu[0] + random.randint(0,search_window_w-patch_size_w),lu[1] + random.randint(0,search_window_h-patch_size_h))


  points_patch = lu_patch
  points = lu
  #print(points,"points",img1.shape)
  points_ref = get_correspondence(dataset1, dataset2,lu[0],lu[1]  )
  points_patch_ref = get_correspondence(dataset1, dataset2,lu_patch[0] ,lu_patch[1] )

  rgb_img1 = cv2.cvtColor(img1, cv2.COLOR_GRAY2RGB)
  rgb_img2 = cv2.cvtColor(img2, cv2.COLOR_GRAY2RGB)

  patch_source = np.zeros((search_window_w, search_window_h), dtype = np.uint8)

  patch_source[int(search_window_w/2 - patch_size_w/2):int(search_window_w/2 + patch_size_w/2),int(search_window_h/2 - patch_size_h/2):int(search_window_h/2 + patch_size_h/2)] = img1[points_patch[0]:points_patch[0]+patch_size_w,points_patch[1]:points_patch[1]+patch_size_h]


  patch_dest = np.zeros((search_window_w, search_window_h), dtype = np.uint8)
  patch_dest[int(search_window_w/2 - patch_size_w/2):int(search_window_w/2 + patch_size_w/2),int(search_window_h/2 - patch_size_h/2):int(search_window_h/2 + patch_size_h/2)]=img2[points_patch_ref[0]:points_patch_ref[0]+patch_size_w,points_patch_ref[1]:points_patch_ref[1]+patch_size_h]



  search_window_source = img1[points[0]:points[0]+search_window_w,points[1]:points[1]+search_window_h]
  search_window_dest = img2[ points_ref[0]:points_ref[0]+search_window_w,points_ref[1] : points_ref[1]+search_window_h]


  Image.fromarray(cv2.cvtColor(patch_dest, cv2.COLOR_GRAY2RGB), "RGB").save("patch.jpeg")
  Image.fromarray(cv2.cvtColor(search_window_source, cv2.COLOR_GRAY2RGB), "RGB").save("search_window.jpeg")

    #draw searching windows




  rgb_img1  = cv2.rectangle(rgb_img1 , tuple(reversed(points)),(points[1]+search_window_h ,points[0]+search_window_w), (0,0,255), 2)
  rgb_img1  = cv2.rectangle(rgb_img1 , tuple(reversed(points_patch)), (points_patch[1]+patch_size_h, points_patch[0]+patch_size_w), (255,0,0), 2)


  #draw patch windows
  rgb_img2  = cv2.rectangle(rgb_img2 , tuple(reversed(points_ref)), ( points_ref[1]+search_window_h,points_ref[0]+search_window_w), (0,0,255), 2)
  rgb_img2  = cv2.rectangle(rgb_img2 , tuple(reversed(points_patch_ref)), ( points_patch_ref[1]+patch_size_h,points_patch_ref[0]+patch_size_w), (255,0,0), 2)

  #print(rgb_img1.shape,search_window_source.shape)


  rgb_img1= np.swapaxes(rgb_img1,0,1)
  rgb_img2= np.swapaxes(rgb_img2,0,1)
  search_window_source= np.swapaxes(search_window_source,0,1)
  patch_source= np.swapaxes(patch_source,0,1)
  search_window_dest= np.swapaxes(search_window_dest,0,1)
  patch_dest= np.swapaxes(patch_dest,0,1)
  if verbose:
      fig, axes = plt.subplots(2, 3)
      axes[0, 0].set_title('source image')
      print(rgb_img1.shape)
      axes[0, 0].imshow(PIL.ImageOps.invert(  Image.fromarray(rgb_img1)))


      axes[0, 1].set_title('search window source')
      axes[0, 1].imshow(PIL.ImageOps.invert(  Image.fromarray( cv2.cvtColor(search_window_source, cv2.COLOR_GRAY2RGB))))

      axes[0, 2].set_title('patch source')
      axes[0, 2].imshow(PIL.ImageOps.invert(  Image.fromarray(cv2.cvtColor(patch_source, cv2.COLOR_GRAY2RGB))))

      axes[1, 0].set_title('dest image')
      axes[1, 0].imshow(PIL.ImageOps.invert(  Image.fromarray(rgb_img2)))

      axes[1, 1].set_title('search window dest')
      axes[1, 1].imshow(PIL.ImageOps.invert(  Image.fromarray(cv2.cvtColor(search_window_dest, cv2.COLOR_GRAY2RGB))))

      axes[1, 2].set_title('patch dest')
      axes[1, 2].imshow(PIL.ImageOps.invert(  Image.fromarray(cv2.cvtColor(patch_dest, cv2.COLOR_GRAY2RGB))))

      plt.show()
  rgb_img1= np.swapaxes(rgb_img1,0,1)
  rgb_img2= np.swapaxes(rgb_img2,0,1)

  return rgb_img1, rgb_img2, points,points_patch_ref,points_patch,dataset1,dataset2

# %%
import torch
import cv2
import numpy as np
import matplotlib.cm as cm


def parse_args():
    # init a costum parser which will be added into pl.Trainer parser
    # check documentation: https://pytorch-lightning.readthedocs.io/en/latest/common/trainer.html#trainer-flags
    parser = argparse.ArgumentParser(formatter_class=argparse.ArgumentDefaultsHelpFormatter)
    parser.add_argument(
        'data_cfg_path', type=str,default=".", help='data config path')
    parser.add_argument(
        '--ckpt_path', type=str, default="weights/indoor_large-SEA.ckpt", help='path to the checkpoint')
    parser.add_argument(
        '--dump_dir', type=str, default=None, help="if set, the matching results will be dump to dump_dir")
    parser.add_argument(
        '--profiler_name', type=str, default='inference', help='options: [inference, pytorch], or leave it unset')
    parser.add_argument(
        '--batch_size', type=int, default=1, help='batch_size per gpu')
    parser.add_argument(
        '--num_workers', type=int, default=2)
    parser.add_argument(
        '--thr', type=float, default=None, help='modify the coarse-level matching threshold.')

    parser = pl.Trainer.add_argparse_args(parser)
    return parser.parse_args()

from src.loftr import LoFTR, default_cfg

from src.utils.plotting import make_matching_figures
from src.config.default import get_cfg_defaults
def get_matcher(image_type):

    matcher = LoFTR(config=default_cfg)
    if image_type == 'indoor':
      matcher.load_state_dict(torch.load("weights/indoor_ds.ckpt")['state_dict'])
    elif image_type == 'outdoor':
      matcher.load_state_dict(torch.load("weights/outdoor_ds.ckpt")['state_dict'])
    #model = PL_LoFTR(config, pretrained_ckpt=args.ckpt_path, profiler=profiler)
    return matcher.eval().cuda()

def get_metrics( mkpts0_r, mkpts1_r,points,points_patch,dataset1,dataset2,searching_window_w,searching_window_h,patch_w,patch_h,img0_raw,img1_raw,color,verbose=False):



                # Extract x and y coordinates from mkpts0
                x0, y0 = zip(*mkpts0_r)

                # Apply translation to the coordinates
                x_conv, y_conv = get_correspondence_multi(dataset1, dataset2, [x+points[1] for x in x0], [y+points[0] for y in y0])

                # Convert the translated coordinates back to tuples
                mk0 = list(zip(x_conv, y_conv))

                # Calculate RMSE
                rmse = 0
                for (x1, y1), (x2, y2) in zip(mk0, mkpts1_r):
                    y2 -= (searching_window_w/2)-(patch_w/2)
                    x2 -= (searching_window_h/2)-(patch_h/2)
                    y2 += points_patch[0]
                    x2 += points_patch[1]

                    rmse += ((x1-x2)**2 + (y1-y2)**2)

                # Normalize the errors by the number of keypoints
                num_kpts = len(mk0)
                rmse=  (rmse/num_kpts)**(1/2) # like in "A Transformer-Based Coarse-to-Fine Wide-Swath SAR Image Registration Method under Weak Texture Conditions"

                return rmse
from src.utils.plotting import make_matching_figure
def predict_and_print(rgb_img1,rgb_img2,matcher,img0_raw,img1_raw,points,points_patch,dataset1,dataset2,searching_window_w,searching_window_h,patch_w,patch_h,verbose=True,experiment=False,configs_ransac=None ):
    '''

        This code performs an image matching task with the given matcher, which takes two raw images and outputs corresponding features. The code first resizes the two raw images to (640, 480) and converts them to torch tensors, normalizing them by dividing each pixel by 255. The two images are then passed to the matcher to get feature matches and confidence scores.
        The code then computes two weighted average points based on the matches, one weighted by the confidence score and the other by a uniform weight. If the number of matches is greater than 0, the code returns the weighted average points and prints them as figures if verbose is set to True. The output figures are saved as "LoFTR-colab-demo.pdf".
I       f there are no matches, the code returns None, None, None, None.
'''


    img0 = torch.from_numpy(img0_raw)[None][None].cuda().to(torch.float) / 255.
    img1 = torch.from_numpy(img1_raw)[None][None].cuda().to(torch.float) / 255.

    batch = {'image0': img0, 'image1': img1}

    # Inference with LoFTR and get prediction
    with torch.no_grad():

            matcher(batch)
            mkpts0 = batch['mkpts0_f'].cpu().numpy()
            mkpts1= batch['mkpts1_f'].cpu().numpy()
            mconf = batch['mconf'].cpu().numpy()

            #mkpts0 = np.array([])

    results = []
    print()
    if mkpts0.shape[0]> 4:

        if configs_ransac is not None:

            for conf in configs_ransac:
                from skimage.measure import ransac
                if conf['residual_threshold']>= 0:
                    model, inliers = ransac((mkpts0, mkpts1),AffineTransform, min_samples=conf['min_samples'], residual_threshold=conf['residual_threshold'], max_trials=conf['max_trials'])
                    n_inliers = np.sum(inliers)
                    if n_inliers is None or n_inliers< 3:
                        conf.update({'rmse':-1,'inliers':0 if n_inliers is None else n_inliers})
                       # results.append({'rmse':-1,'inliers':})
                    else:
                        rmse = get_metrics(mkpts0[inliers], mkpts1[inliers],points,points_patch,dataset1,dataset2,searching_window_w,searching_window_h,patch_w,patch_h,rgb_img1,rgb_img2,mconf[inliers],verbose=verbose)
                else:
                     rmse= get_metrics(mkpts0, mkpts1,points,points_patch,dataset1,dataset2,searching_window_w,searching_window_h,patch_w,patch_h,rgb_img1,rgb_img2,mconf,verbose=verbose)
                     n_inliers = mkpts0.shape[0]
                conf.update({'rmse':rmse,'inliers':n_inliers})
                results.append(conf)
                if conf['residual_threshold'] == 1:

                    color = cm.jet(mconf, alpha=0.7)
                    text = [
                        'LoFTR',
                        'Matches: {}'.format(len(mkpts0)),
                    ]
                    if verbose:
                        #rgb_img1= np.swapaxes(rgb_img1,0,1)
                        #rgb_img2= np.swapaxes(rgb_img2,0,1)
                        abs_m0 = np.array([(x+points[1],y+points[0]) for x,y in mkpts0[inliers]])
                        abs_m1 = np.array([(x-((searching_window_h/2)-(patch_h/2))+points_patch[1] ,y-((searching_window_w/2)-(patch_w/2))+points_patch[0]) for x,y in mkpts1[inliers]])
                        fig = make_matching_figure(rgb_img1, rgb_img2, abs_m0, abs_m1, color[inliers], abs_m0, abs_m1, text)
                        make_matching_figure(rgb_img1, rgb_img2, abs_m0, abs_m1, color[inliers], abs_m0, abs_m1, text, path="LoFTR-colab-demo.pdf")

                        fig = make_matching_figure(img0_raw, img1_raw, mkpts0[inliers], mkpts1[inliers], color[inliers], mkpts0[inliers], mkpts1[inliers], text)
                        make_matching_figure(img0_raw, img1_raw, mkpts0[inliers], mkpts1[inliers], color[inliers], mkpts0[inliers], mkpts1[inliers], text, path="LoFTR-colab-demo.pdf")
        return results
    return None

# %%
from torch import nn
from torchvision.transforms import functional as F
import os
import numpy as np
import torch
from despekle.transform_main import TransSAR, TransSARV2, TransSARV3
import cv2

loaddirec = "model.pth"
save_path = "./"

device = torch.device("cuda")
if model_TransSAR is None:
    model_TransSAR = TransSARV2()
    model_TransSAR .to(device)
    model_TransSAR = nn.DataParallel(model_TransSAR ,device_ids=[0]).cuda()
    model_TransSAR.load_state_dict(torch.load(loaddirec))
    model_TransSAR.eval()

# %%
'''
 It takes two images as input, performs image denoising, and then uses a matcher to find the similarity between a patch from the first image and the second image.

The code uses a loop to run the processing for 50 times, for each iteration:

It calls the function get_sample to get the images, points, and datasets.
It denoises the raw images using 3 denoising methods (mean, bilateral, and lee_enhanced). If the denoising didn't produce a result, the code skips to the next iteration.
The code calls the function predict_and_print to get the result of the matcher and to find the similarity between the patch and the search window.
The code uses the result of the matcher to calculate the error in meters between the predicted position and the real position.
The code draws circles on the original full map to show the predicted and real positions.
The code displays the original full map if verbose is set to True.
The code accumulates the error for each iteration and prints the final result, which includes the number of successful predictions and the mean error in meters.
'''
def lee_filter(img, size):
    img_mean = uniform_filter(img, (size, size))
    img_sqr_mean = uniform_filter(img**2, (size, size))
    img_variance = img_sqr_mean - img_mean**2

    overall_variance = variance(img)

    img_weights = img_variance / (img_variance + overall_variance)
    img_output = img_mean + img_weights * (img - img_mean)
    return img_output
def get_smoothed(file,savefile):
    im_file = file
    img = cv2.imread(im_file,0)

    #noisy_im = (np.float32(img)+1.0)/256.0

    #x = np.float32(noisy_im)
    #x = F.to_tensor(x)
    #x = x.unsqueeze(0)


    #pred_im = model_TransSAR(x)
    #tmp = pred_im.detach().cpu().numpy()

    #tmp = tmp.squeeze()
    #tmp = tmp*256 -1

    filepath_out = savefile

    cv2.imwrite(filepath_out,img)

def do_test(matcher_in,path0,path1,size_search=(640, 480),size_patch=(int(180*1.333333), int(180)),configs_ransac=None,verbose=True):


  rgb_img1, rgb_img2, points,points_patch_ref,points_patch,dataset1,dataset2 = get_sample(path0,path1,size_search,size_patch,verbose=verbose)
  if rgb_img1 is None:
      return None
  img0_pth = "./search_window.jpeg"
  img1_pth = "./patch.jpeg"
  get_smoothed("search_window.jpeg","search_window_s.jpeg")
  get_smoothed("patch.jpeg","patch_s.jpeg")
  image_pair = ["search_window_s.jpeg", "patch_s.jpeg"]
  img0_raw = cv2.imread(image_pair[0], cv2.IMREAD_GRAYSCALE)
  img1_raw = cv2.imread(image_pair[1], cv2.IMREAD_GRAYSCALE)

  img0_denoised =img0_raw
  img1_denoised = img1_raw

  results = predict_and_print(rgb_img1,rgb_img2,matcher_in,img0_denoised,img1_denoised,points,points_patch,dataset1,dataset2, size_search[0],size_search[1],size_patch[0],size_patch[1],verbose=verbose,configs_ransac=configs_ransac)

  return results

def get_list():
    path_of_the_directory= './data/paired_sentinel/'
    paths = []
    for filename in os.listdir(path_of_the_directory):
        f = os.path.join(path_of_the_directory,filename)
        if not os.path.isfile(f):
            lst = os.listdir(f)
            if len(lst)>1:
                paths.append((os.path.join(path_of_the_directory,filename,lst[0]),os.path.join(path_of_the_directory,filename,lst[1])))
    return paths

# %%
matcher_in=get_matcher("outdoor")
verbose=False
random.seed(9)
count_yes= 0
test_for_each_pair=1
configs_ransac=[{'min_samples':0,'residual_threshold':-1,'max_trials':0},
                {'min_samples':4,'residual_threshold':1,'max_trials':10000},
                      {'min_samples':4,'residual_threshold':3,'max_trials':10000},
                      {'min_samples':4,'residual_threshold':5,'max_trials':10000},
                      {'min_samples':4,'residual_threshold':10,'max_trials':10000},
                      {'min_samples':4,'residual_threshold':20,'max_trials':10000}]
paths = get_list()

metrics = [{'rmse':0,'inliers':0,'accepted_match':0} for conf in range(len(configs_ransac))]

for path0,path1 in paths:
    for x in range(test_for_each_pair):
              if random.randint(0, 1):
                results = do_test(matcher_in,path0,path1,size_search=(640, 480),size_patch=(int(180*1.333333)*2, int(180)*2),verbose=verbose,configs_ransac=configs_ransac)
              else:
                results = do_test(matcher_in,path1,path0,size_search=(640, 480),size_patch=(int(180*1.333333)*2, int(180)*2),verbose=verbose,configs_ransac=configs_ransac)

              if results is not None:

                for i in range(len(results)):
                    if metrics[i]['rmse']>=0:

                        if results[i]['inliers'] is not None:
                            metrics[i]['rmse'] += results[i]['rmse']
                            metrics[i]['inliers'] += results[i]['inliers']
                            metrics[i]['accepted_match'] +=1
                    print(results[i])

                count_yes+=1

data = []
for i in range(len(metrics)):
        metrics[i]['rmse'] /= metrics[i]['accepted_match']
        metrics[i]['inliers'] /= metrics[i]['accepted_match']

        configs_ransac[i]['rmse'] = metrics[i]['rmse']
        configs_ransac[i]['inliers'] = metrics[i]['inliers']
        configs_ransac[i]['Accepted_match'] = metrics[i]['accepted_match']
        configs_ransac[i]['total_match'] = test_for_each_pair*len(paths)
        data.append( configs_ransac[i])
            #print("Configuration:",configs_ransac[i-1]," Metrics:",metrics[i], " Accepted_match:", metrics[i]['accepted_match'] ,"/", test_for_each_pair*len(paths))




import pandas as pd



df = pd.DataFrame.from_dict(data)

print (df)

df.to_excel('players.xlsx')
# Out:
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 44.05519617958437, 'inliers': 31}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 2.3776871592979085, 'inliers': 10}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 3.061656666218341, 'inliers': 19}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 3.39816205240859, 'inliers': 22}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 4.5460565598035085, 'inliers': 26}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 8.100829794563376, 'inliers': 27}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 111.44797515240582, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 111.44797515240582, 'inliers': 1}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 111.44797515240582, 'inliers': 2}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 111.44797515240582, 'inliers': 2}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 122.7202296635307, 'inliers': 4}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 122.7202296635307, 'inliers': 4}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 71.32124709490884, 'inliers': 15}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 4.740873218347332, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 5.215069741200917, 'inliers': 8}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 5.068015113041727, 'inliers': 9}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 5.107715460488406, 'inliers': 11}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 5.107715460488406, 'inliers': 11}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 70.26917426277882, 'inliers': 13}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 6.175778404047209, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 5.4251384405528364, 'inliers': 8}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 5.222353919301088, 'inliers': 9}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 5.222353919301088, 'inliers': 9}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 5.222353919301088, 'inliers': 9}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 20.609736452478746, 'inliers': 18}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 4.917057210666592, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 3.9279621408492655, 'inliers': 13}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 4.268561038653585, 'inliers': 15}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 4.708643117530576, 'inliers': 17}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 4.708643117530576, 'inliers': 17}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 156.22042612985, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 156.22042612985, 'inliers': None}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 156.22042612985, 'inliers': None}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 156.22042612985, 'inliers': None}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 156.22042612985, 'inliers': 1}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 156.22042612985, 'inliers': 1}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 25.018476477196437, 'inliers': 36}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 3.1542597313601823, 'inliers': 15}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 3.3995564463622556, 'inliers': 23}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 3.683501682623893, 'inliers': 30}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 3.884507554142161, 'inliers': 32}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 5.265890361147161, 'inliers': 33}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 114.87543335099748, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 114.87543335099748, 'inliers': None}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 114.87543335099748, 'inliers': None}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 114.87543335099748, 'inliers': 1}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 114.87543335099748, 'inliers': 2}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 141.68705400516203, 'inliers': 4}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 20.975519866249446, 'inliers': 68}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 6.4534813646172084, 'inliers': 20}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 6.412861151770877, 'inliers': 41}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 5.695542522578539, 'inliers': 53}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 6.265906402038577, 'inliers': 62}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 6.793640336705284, 'inliers': 63}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 71.18273371604101, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 71.18273371604101, 'inliers': None}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 71.18273371604101, 'inliers': 1}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 71.18273371604101, 'inliers': 1}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 71.18273371604101, 'inliers': 1}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 63.57388473329836, 'inliers': 4}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 48.04245873321381, 'inliers': 64}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 4.133256765948222, 'inliers': 15}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 4.445744273024896, 'inliers': 28}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 4.454677550195542, 'inliers': 44}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 4.774367463263366, 'inliers': 60}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 4.774367463263366, 'inliers': 60}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 71.76206720829698, 'inliers': 24}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 3.9461346852794414, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 6.484017706276595, 'inliers': 10}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 3.565496239288091, 'inliers': 13}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 17.67250136453715, 'inliers': 15}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 16.854891597098106, 'inliers': 18}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 24.453382922866734, 'inliers': 84}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 4.330222767627229, 'inliers': 23}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 4.910652884557754, 'inliers': 54}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 4.91906220305495, 'inliers': 76}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 4.930690276872455, 'inliers': 81}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 4.930690276872455, 'inliers': 81}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 48.51919139663887, 'inliers': 21}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 5.080052923349234, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 5.147096452741952, 'inliers': 13}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 5.234797836775975, 'inliers': 16}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 5.310796462585318, 'inliers': 18}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 5.310796462585318, 'inliers': 18}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 74.94964380704128, 'inliers': 14}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 108.32271389970423, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 98.86845862732089, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 31.57680668136747, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 49.996215569389165, 'inliers': 8}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 58.21469027777987, 'inliers': 10}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 51.33835625684476, 'inliers': 18}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 3.6660854514916474, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 3.8814391963723924, 'inliers': 8}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 7.293950177860578, 'inliers': 10}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 6.663799115654337, 'inliers': 13}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 30.4795597169495, 'inliers': 15}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 20.973848077169702, 'inliers': 77}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 3.111416545717039, 'inliers': 22}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 3.5249367159871126, 'inliers': 48}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 4.1341971471739285, 'inliers': 66}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 4.4452391835311635, 'inliers': 74}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 4.4452391835311635, 'inliers': 74}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 193.41474570715596, 'inliers': 9}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 172.05348019037754, 'inliers': 4}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 182.35632166661293, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 182.35632166661293, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 182.35632166661293, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 194.10529364738403, 'inliers': 6}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 139.66555074438273, 'inliers': 11}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 139.66555074438273, 'inliers': 2}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 138.05001867573253, 'inliers': 4}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 190.39328131084199, 'inliers': 4}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 170.44993141601077, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 160.76316753892868, 'inliers': 6}
#
#
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 158.71140200223525, 'inliers': 12}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 102.40748158959795, 'inliers': 4}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 102.67363301100085, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 99.51303666233302, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 136.87885999275605, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 92.70968922821369, 'inliers': 6}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 218.11277431660034, 'inliers': 12}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 252.98320441667897, 'inliers': 4}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 249.33496084963534, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 208.79179308546816, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 225.1523141064605, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 225.1523141064605, 'inliers': 7}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 67.47323503707374, 'inliers': 15}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 47.62765944073617, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 53.102408632070954, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 52.53711769772771, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 51.61805732849712, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 56.8494711881586, 'inliers': 8}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 131.79636433409388, 'inliers': 13}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 158.71349062545306, 'inliers': 4}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 142.35231225500291, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 10.119768607414274, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 40.712974581206886, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 90.83475469438254, 'inliers': 9}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 11.372954765162438, 'inliers': 161}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 2.2979262841088217, 'inliers': 64}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 2.8961222581540396, 'inliers': 137}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 2.950754854303449, 'inliers': 145}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 3.413758560886591, 'inliers': 154}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 6.5272479782477575, 'inliers': 157}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 162.9390624478584, 'inliers': 9}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 169.9011058206313, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 169.9011058206313, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 122.52523214032477, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 122.52523214032477, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 140.45531632553897, 'inliers': 7}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 50.695729508385455, 'inliers': 40}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 3.0411778825556675, 'inliers': 18}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 3.1396275392063857, 'inliers': 28}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 3.1246746420628857, 'inliers': 29}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 4.162115258588093, 'inliers': 31}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 9.391261820092208, 'inliers': 33}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 73.9449606408437, 'inliers': 11}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 40.1343036942403, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 41.331932984500874, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 37.76963626988267, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 37.76963626988267, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 33.07130800404128, 'inliers': 8}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 58.23902056767554, 'inliers': 36}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 1.4094376093673437, 'inliers': 15}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 1.8429870742115224, 'inliers': 26}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 3.0996744357929957, 'inliers': 27}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 3.308514039866414, 'inliers': 29}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 3.308514039866414, 'inliers': 29}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 27.052478108112954, 'inliers': 60}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 2.93575959405098, 'inliers': 23}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 3.461122934764791, 'inliers': 42}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 3.774846540752216, 'inliers': 49}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 4.402671803412294, 'inliers': 54}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 4.5669876682342165, 'inliers': 55}
#
#
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 111.41434649313258, 'inliers': 12}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 96.12991681940554, 'inliers': 4}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 96.12991681940554, 'inliers': 4}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 132.03596156376227, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 117.83835871473181, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 95.30981055416073, 'inliers': 5}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 60.980217138120935, 'inliers': 13}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 5.012533348258581, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 5.213253844824999, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 4.801367120754927, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 29.429467781705682, 'inliers': 9}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 40.775084608319304, 'inliers': 10}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 129.75740333299032, 'inliers': 13}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 35.35455286566912, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 66.55412081743304, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 32.314413162144454, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 82.04275516997272, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 103.19860871231695, 'inliers': 8}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 216.3650949684828, 'inliers': 10}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 267.7265564523613, 'inliers': 4}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 242.86833651540536, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 217.93807670784423, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 217.93807670784423, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 230.37864223391458, 'inliers': 8}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 127.42054591670953, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 127.42054591670953, 'inliers': None}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 127.42054591670953, 'inliers': 1}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 110.2759999917322, 'inliers': 3}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 105.87822697804312, 'inliers': 4}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 105.87822697804312, 'inliers': 4}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 53.81624119382174, 'inliers': 33}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 2.064911293114747, 'inliers': 14}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 2.7797304904808566, 'inliers': 25}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 3.061316517417461, 'inliers': 30}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 3.061316517417461, 'inliers': 30}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 3.061316517417461, 'inliers': 30}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 62.17438606474027, 'inliers': 37}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 1.9016682016730138, 'inliers': 10}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 2.174854078447148, 'inliers': 18}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 3.3558085042219, 'inliers': 23}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 3.4606539138888617, 'inliers': 24}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 8.952796251112726, 'inliers': 27}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 45.83279338959706, 'inliers': 78}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 26.887628803106807, 'inliers': 21}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 27.037079196998107, 'inliers': 56}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 26.956535718624853, 'inliers': 67}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 26.900656983164733, 'inliers': 71}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 27.043360985854715, 'inliers': 73}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 62.0594782464064, 'inliers': 21}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 2.400490239077154, 'inliers': 11}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 2.901206862631028, 'inliers': 13}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 2.901206862631028, 'inliers': 13}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 2.901206862631028, 'inliers': 13}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 40.63278079816754, 'inliers': 14}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 119.35861924920358, 'inliers': 16}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 6.381953906630378, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 110.5000305407597, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 140.6047100699682, 'inliers': 8}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 125.81267180885386, 'inliers': 10}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 115.63260645878005, 'inliers': 11}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 51.98438019313068, 'inliers': 23}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 3.2799859178430726, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 3.680681754784603, 'inliers': 12}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 3.7838247622404193, 'inliers': 15}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 3.760526561439048, 'inliers': 16}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 19.227202277666162, 'inliers': 18}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 118.21051213971485, 'inliers': 11}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 118.21051213971485, 'inliers': 2}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 36.00602306926128, 'inliers': 4}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 64.9792589849587, 'inliers': 4}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 92.63825972905987, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 48.682435118794785, 'inliers': 6}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 80.49202902945625, 'inliers': 42}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 26.629425990249842, 'inliers': 15}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 26.61356782373199, 'inliers': 22}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 27.28364905254644, 'inliers': 26}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 26.86286855999088, 'inliers': 32}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 27.67810523804967, 'inliers': 33}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 77.92356687980315, 'inliers': 8}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 77.92356687980315, 'inliers': 2}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 97.99279911810044, 'inliers': 4}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 97.99279911810044, 'inliers': 4}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 88.4278713065627, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 82.37762189362165, 'inliers': 6}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 51.53585808498027, 'inliers': 39}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 4.436124404853599, 'inliers': 11}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 4.178924111478812, 'inliers': 18}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 3.9357768332735743, 'inliers': 26}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 6.50906316258203, 'inliers': 32}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 8.404015281970148, 'inliers': 35}
#
#
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 42.981629766967515, 'inliers': 35}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 0.9196515230844179, 'inliers': 14}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 3.0868627939269877, 'inliers': 22}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 3.334249592410199, 'inliers': 29}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 4.0290831639800455, 'inliers': 31}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 4.0290831639800455, 'inliers': 31}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 49.07271286885051, 'inliers': 99}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 2.8712969609411725, 'inliers': 29}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 3.3106993001114056, 'inliers': 68}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 3.467957680784199, 'inliers': 81}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 4.252787037651447, 'inliers': 90}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 4.722100610259183, 'inliers': 91}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 72.92192899216575, 'inliers': 16}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 45.986076303192746, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 38.945971868227794, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 4.978119032809586, 'inliers': 8}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 52.35810784916536, 'inliers': 10}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 50.62891286521943, 'inliers': 11}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 80.68245176643872, 'inliers': 8}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 80.68245176643872, 'inliers': 1}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 80.68245176643872, 'inliers': 2}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 80.68245176643872, 'inliers': 2}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 48.97416543106025, 'inliers': 4}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 68.79572161934466, 'inliers': 5}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 91.34783584693378, 'inliers': 20}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 2.4659355439039854, 'inliers': 8}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 2.6995144820970918, 'inliers': 14}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 3.1282091255105184, 'inliers': 16}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 3.1282091255105184, 'inliers': 16}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 3.1282091255105184, 'inliers': 16}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 59.74524243141447, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 59.74524243141447, 'inliers': 1}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 59.74524243141447, 'inliers': 2}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 41.42993975576338, 'inliers': 3}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 58.68816356447618, 'inliers': 4}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 58.68816356447618, 'inliers': 4}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 140.6297741255419, 'inliers': 8}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 175.96160999472136, 'inliers': 4}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 175.96160999472136, 'inliers': 4}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 75.23891479388938, 'inliers': 4}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 75.23891479388938, 'inliers': 4}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 108.43440709918242, 'inliers': 5}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 84.24192798676783, 'inliers': 8}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 5.012948326630983, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 4.808211546713295, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 65.14319648023091, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 84.24192798676783, 'inliers': 8}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 84.24192798676783, 'inliers': 8}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 35.2278929606681, 'inliers': 28}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 1.841705898263213, 'inliers': 14}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 2.237154856415318, 'inliers': 22}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 2.583280961674439, 'inliers': 25}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 3.1134812401640866, 'inliers': 26}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 3.1134812401640866, 'inliers': 26}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 36.15006345004024, 'inliers': 118}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 1.230032290130589, 'inliers': 46}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 1.485189962170989, 'inliers': 101}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 1.734599807984428, 'inliers': 103}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 3.404611253929986, 'inliers': 114}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 3.404611253929986, 'inliers': 114}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 65.32075571264366, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 65.32075571264366, 'inliers': None}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 65.32075571264366, 'inliers': 1}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 65.32075571264366, 'inliers': 2}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 75.97572479588771, 'inliers': 3}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 65.80114389303675, 'inliers': 4}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 30.679645532838464, 'inliers': 41}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 2.9002056308644644, 'inliers': 14}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 3.8173011355906987, 'inliers': 24}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 3.795709596379282, 'inliers': 31}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 4.611009765455282, 'inliers': 39}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 4.611009765455282, 'inliers': 39}
#
#
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 156.32481411768265, 'inliers': 11}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 162.72036849809416, 'inliers': 4}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 186.5244041678301, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 176.73754605468244, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 176.73754605468244, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 170.48734275887418, 'inliers': 6}
#
#
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 104.49636457755196, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 104.49636457755196, 'inliers': None}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 104.49636457755196, 'inliers': 2}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 119.56673764994676, 'inliers': 3}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 125.25004429309176, 'inliers': 4}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 125.86765581441755, 'inliers': 4}
#
#
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 62.242401257634505, 'inliers': 8}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 18.850642250031875, 'inliers': 4}
# {'min_samples': 4, 'residual_threshold': 3, 'max_trials': 10000, 'rmse': 25.214572724801613, 'inliers': 4}
# {'min_samples': 4, 'residual_threshold': 5, 'max_trials': 10000, 'rmse': 60.670606813630684, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 10, 'max_trials': 10000, 'rmse': 60.670606813630684, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 20, 'max_trials': 10000, 'rmse': 61.13306369080635, 'inliers': 5}
#    min_samples  residual_threshold  max_trials       rmse    inliers  \
# 0            0                  -1           0  81.708882  28.423729
# 1            4                   1       10000  49.067086  10.773585
# 2            4                   3       10000  53.301144  18.263158
# 3            4                   5       10000  49.707076  21.327586
# 4            4                  10       10000  55.684989  23.457627
# 5            4                  20       10000  58.245181  24.355932
#
#    Accepted_match  total_match
# 0              59           64
# 1              53           64
# 2              57           64
# 3              58           64
# 4              59           64
# 5              59           64

# %%
import pandas as pd



df = pd.DataFrame.from_dict(data)

print (df)

df.to_excel('players.xlsx')
# Out:
#    min_samples  residual_threshold  max_trials       rmse    inliers  \
# 0            0                  -1           0  81.708882  28.423729
# 1            4                   1       10000  49.067086  10.773585
# 2            4                   3       10000  53.301144  18.263158
# 3            4                   5       10000  49.707076  21.327586
# 4            4                  10       10000  55.684989  23.457627
# 5            4                  20       10000  58.245181  24.355932
#
#    Accepted_match  total_match
# 0              59           64
# 1              53           64
# 2              57           64
# 3              58           64
# 4              59           64
# 5              59           64
