# %% [markdown]
# # Readme: how to handle our Sentinel-1 ASC-DESC dataset
#
# ###What you have:
# A list of big geotiff file (.tif) Pairs. Each image in the pair should roughly correspond to the same area as the other. Each geotiff can by read using rasterio or gdal, as you can see in the notebook.
#
# ###What you should do:
# create single datapoints to train/test your models.
#
# ###How to do it:
# For each big pair, get a datapoint by cropping a random patch from one side (this acts as the "query" patch, the one you want to look for) and cropping a patch around the same coordinates from the other side (this acts as the "search" patch, the one to want to search in). Add distortions: search patch has to be taken with a random offset around query patch (perhaps random but normally distributed around offset 0, which means query patch at the centre). Also add a bit of random scale and rotation.Try finding a 1km^2 query patch inside a 4km^2 search patch.
#
# ###Some WARNINGS (not too sure about them)
#
# Warning: do not include every correspondence in the ground truth pixel correspondence list! you should only insert meaningful correspondences such as harris corners.
#
# Warning: maybe discard a candidate query altogether if it's not feature-rich enough. You can do this using pixel histograms (has to have more than n peaks -> use scikit learn), or maybe entropy. for example, if every pixel is around e.g. 150, this means that everything is gray and unmatchable.

# %%
import PIL
from PIL import Image
from scipy.ndimage import uniform_filter, variance
from skimage.transform import AffineTransform



from src.loftr import LoFTR
from src.loftr.utils.cvpr_ds_config import default_cfg
from src.utils.plotting import make_matching_figure


! pip install rasterio
import rasterio as rio
from rasterio import warp
import matplotlib
from matplotlib import pyplot as plt

import argparse

import pytorch_lightning as pl

# Need this to plot in HD
# This takes up a lot of memory!
matplotlib.rcParams['figure.dpi'] = 300

if 'model_TransSAR' not in locals():
    model_TransSAR = None
# Out:
# Requirement already satisfied: rasterio in /home/fred/anaconda3/envs/pythonProject/lib/python3.10/site-packages (1.3.5.post1)
# Requirement already satisfied: certifi in /home/fred/anaconda3/envs/pythonProject/lib/python3.10/site-packages (from rasterio) (2022.12.7)
# Requirement already satisfied: setuptools in /home/fred/anaconda3/envs/pythonProject/lib/python3.10/site-packages (from rasterio) (65.6.3)
# Requirement already satisfied: click-plugins in /home/fred/anaconda3/envs/pythonProject/lib/python3.10/site-packages (from rasterio) (1.1.1)
# Requirement already satisfied: click>=4.0 in /home/fred/anaconda3/envs/pythonProject/lib/python3.10/site-packages (from rasterio) (8.1.3)
# Requirement already satisfied: attrs in /home/fred/anaconda3/envs/pythonProject/lib/python3.10/site-packages (from rasterio) (22.2.0)
# Requirement already satisfied: affine in /home/fred/anaconda3/envs/pythonProject/lib/python3.10/site-packages (from rasterio) (2.4.0)
# Requirement already satisfied: cligj>=0.5 in /home/fred/anaconda3/envs/pythonProject/lib/python3.10/site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: snuggs>=1.4.1 in /home/fred/anaconda3/envs/pythonProject/lib/python3.10/site-packages (from rasterio) (1.4.7)
# Requirement already satisfied: numpy>=1.18 in /home/fred/anaconda3/envs/pythonProject/lib/python3.10/site-packages (from rasterio) (1.23.4)
# Requirement already satisfied: pyparsing>=2.1.6 in /home/fred/anaconda3/envs/pythonProject/lib/python3.10/site-packages (from snuggs>=1.4.1->rasterio) (3.0.9)

# %%
def get_correspondence_multi(src_data, dst_data, src_row, src_col):
    ''' Gets the pixel coordinates (dst_row,dst_col) in dst_data of a given pixel at (src_row,src_col) in src_data.
        Warning: no handling of pixel being outside dst_data! You have to handle that yourself.
        TODO: Should add a check to only get the correspondences with high enough cornerness on both sides
        (because we should only insert meaningful correspondences in the list!).
    '''
    # Get geo coords of pixel from src dataset
    X1, Y1 = rio.transform.xy(src_data.transform, src_row, src_col)
    # print("Geographic coordinates in crs 1: ",X1,Y1)

    if src_data.crs != dst_data.crs:
        # convert coordinates in the crs of the dst dataset
        X2, Y2 = warp.transform(src_data.crs, dst_data.crs, X1, Y1)
    else:
        # if the crs is the same, do nothing
        X2, Y2 = X1, Y1

    # Get corresponding px coords in dst dataset
    # It still returns an index even if out of bounds
    dst_row, dst_col = rio.transform.rowcol(dst_data.transform, X2, Y2)
    # print("Corresponding pixel coordinates in image 2: ",dst_row,dst_col)
    return dst_row, dst_col


def get_correspondence(src_data, dst_data, src_row, src_col):
    ''' Gets the pixel coordinates (dst_row,dst_col) in dst_data of a given pixel at (src_row,src_col) in src_data.
        Warning: no handling of pixel being outside dst_data! You have to handle that yourself.
        TODO: Should add a check to only get the correspondences with high enough cornerness on both sides
        (because we should only insert meaningful correspondences in the list!).
    '''
    # Get geo coords of pixel from src dataset
    X1, Y1 = src_data.xy(src_row, src_col)
    X1, Y1 = X1 if type(X1) is list else [X1], Y1 if type(Y1) is list else [Y1]
    #print("Geographic coordinates in crs 1: ",X1,Y1)

    if src_data.crs != dst_data.crs:
        # convert coordinates in the crs of the dst dataset
        X2, Y2 = warp.transform(src_data.crs, dst_data.crs, X1, Y1)
        X2 = X2[0]
        Y2 = Y2[0]
    else:
        # if the crs is the same, do nothing
        X2, Y2 = X1, Y1

    # Get corresponding px coords in dst dataset
    # It still returns an index even if out of bounds
    dst_row, dst_col = dst_data.index(X2, Y2)
    dst_row, dst_col = dst_row[0] if type(dst_row) is list else dst_row, dst_col[0] if type(
        dst_col) is list else dst_col
    if dst_row < 0 or dst_col < 0:
        print("make the margin higher, the corresponding points are outside the image")
    #print("Corresponding pixel coordinates in image 2: ",dst_row,dst_col)
    return dst_row, dst_col


def get_datapoint(ref_data, query_data):
    ''' TODO: Call this method on a pair of rasterio datasets. It will generate a random datapoint consisting
        of a smaller SAR patch from the query dataset, and a bigger SAR patch from the reference dataset.
        The search patch contains the area of the smaller patch, with a random offset.
    '''
    datapoint = None
    return datapoint


def is_good_patch(patch):
    ''' TODO: Checks if the random query patch is sufficiently texture-rich to be used to train/test the matching model.
        If the patch is too plain (e.g. sea or desert), returns False. This function should also be used at test time:
        if a sensor image is too plain, there's no need to match it.
        At test time, something similar should also be done on the reference side.
    '''
    good = None
    return good


def get_keypoints(patch):
    ''' TODO: Use something like harris corner detection to get the list of ground truth correspondences.
        In fact, you should not train on each pixel corresp, but you should select only meaningful corresp!
        Harris peaks might be just strong speckle noise, but if you take strong ones you should be fine.
    '''
    keypoints = None
    return keypoints


def normalize_image(img):
    ''' Normalize by clipping to 99th percentile and convert to uint8.
        This clips strong speckle outliers and optimizes the brightness range
    '''
    p1 = np.nanpercentile(img, 99)
    img = img.clip(0, p1)
    img = (img - np.nanmin(img)) / (np.nanmax(img) - np.nanmin(img)) * 255
    img = img.astype(np.uint8, copy=True)
    return img

# %%
paths = [
    './data/paired_sentinel/Sentinel1-AD Dataset- Lat-0.015502064951149919Lon41.3552557262833/S1A_IW_GRDH_1SDV_20220808T060138_20220808T060203_044457_054E18_B16D.tif',
    './data/paired_sentinel/Sentinel1-AD Dataset- Lat-0.015502064951149919Lon41.3552557262833/S1A_IW_GRDH_1SDV_20220814T175523_20220814T175548_044552_055140_2AEA.tif']

import random


def get_sample(tiff1_path, tiff2_path, search_window, patch_size, margin=40, random_seed=1, verbose=True,
               random_rotation=0.03, random_zoom=0.03):
    '''
          1-Reads the first band of the TIFF files using the rio library and normalizes the image data.
          2-Selects a random search window and patch location within the image using random number generators.
          3-Calls the get_correspondence function on the selected locations to find the corresponding locations in the second image.
          4-Converts the grayscale images to RGB format using OpenCV.
          5-Creates centered patches from the RGB images by zero-padding the images and copying a portion of the original images to the patches.
          6-Draws rectangles around the search window and patch in both images.
          7-Saves the patch and search window as JPEG files.
          8-Returns the processed RGB images, the points of the search window and patch, and the original rio datasets.

    '''
    dataset1 = rio.open(tiff1_path)
    dataset2 = rio.open(tiff2_path)
    img1 = dataset1.read(1)
    img1 = normalize_image(img1)
    img2 = dataset2.read(1)
    img2 = normalize_image(img2)

    img1 = np.swapaxes(img1, 0, 1)
    img2 = np.swapaxes(img2, 0, 1)

    search_window_w, search_window_h = search_window
    patch_size_w, patch_size_h = patch_size

    if img1.shape[0] - search_window_w - margin * 2 < 0 or img1.shape[1] - search_window_h - margin * 2 < 0:
        print("margin + search windows is too big for the image:", margin, "*2 +", (search_window_w, search_window_h),
              ">", img1.shape)
        return None, None, None, None, None, None, None
    lu = (margin + random.randint(0, img1.shape[0] - search_window_w - margin * 2),
          margin + random.randint(0, img1.shape[1] - search_window_h - margin * 2))
    lu_patch = (lu[0] + random.randint(0, search_window_w - patch_size_w),
                lu[1] + random.randint(0, search_window_h - patch_size_h))

    points_patch = lu_patch
    points = lu
    #print(points,"points",img1.shape)
    points_ref = get_correspondence(dataset1, dataset2, lu[0], lu[1])
    points_patch_ref = get_correspondence(dataset1, dataset2, lu_patch[0], lu_patch[1])

    rgb_img1 = cv2.cvtColor(img1, cv2.COLOR_GRAY2RGB)
    rgb_img2 = cv2.cvtColor(img2, cv2.COLOR_GRAY2RGB)

    patch_source = np.zeros((search_window_w, search_window_h), dtype=np.uint8)

    patch_source[int(search_window_w / 2 - patch_size_w / 2):int(search_window_w / 2 + patch_size_w / 2),
    int(search_window_h / 2 - patch_size_h / 2):int(search_window_h / 2 + patch_size_h / 2)] = img1[points_patch[0]:
                                                                                                    points_patch[
                                                                                                        0] + patch_size_w,
                                                                                               points_patch[1]:
                                                                                               points_patch[
                                                                                                   1] + patch_size_h]

    patch_dest = np.zeros((search_window_w, search_window_h), dtype=np.uint8)
    patch_dest[int(search_window_w / 2 - patch_size_w / 2):int(search_window_w / 2 + patch_size_w / 2),
    int(search_window_h / 2 - patch_size_h / 2):int(search_window_h / 2 + patch_size_h / 2)] = img2[points_patch_ref[0]:
                                                                                                    points_patch_ref[
                                                                                                        0] + patch_size_w,
                                                                                               points_patch_ref[1]:
                                                                                               points_patch_ref[
                                                                                                   1] + patch_size_h]

    search_window_source = img1[points[0]:points[0] + search_window_w, points[1]:points[1] + search_window_h]
    search_window_dest = img2[points_ref[0]:points_ref[0] + search_window_w,
                         points_ref[1]: points_ref[1] + search_window_h]



    #draw searching windows

    rgb_img1 = cv2.rectangle(rgb_img1, tuple(reversed(points)),
                             (points[1] + search_window_h, points[0] + search_window_w), (0, 0, 255), 2)
    rgb_img1 = cv2.rectangle(rgb_img1, tuple(reversed(points_patch)),
                             (points_patch[1] + patch_size_h, points_patch[0] + patch_size_w), (255, 0, 0), 2)

    #draw patch windows
    rgb_img2 = cv2.rectangle(rgb_img2, tuple(reversed(points_ref)),
                             (points_ref[1] + search_window_h, points_ref[0] + search_window_w), (0, 0, 255), 2)
    rgb_img2 = cv2.rectangle(rgb_img2, tuple(reversed(points_patch_ref)),
                             (points_patch_ref[1] + patch_size_h, points_patch_ref[0] + patch_size_w), (255, 0, 0), 2)

    #print(rgb_img1.shape,search_window_source.shape)

    rgb_img1 = np.swapaxes(rgb_img1, 0, 1)
    rgb_img2 = np.swapaxes(rgb_img2, 0, 1)
    search_window_source = np.swapaxes(search_window_source, 0, 1)
    patch_source = np.swapaxes(patch_source, 0, 1)
    search_window_dest = np.swapaxes(search_window_dest, 0, 1)
    patch_dest = np.swapaxes(patch_dest, 0, 1)
    if verbose:
        fig, axes = plt.subplots(2, 3)
        axes[0, 0].set_title('source image')
        print(rgb_img1.shape)
        axes[0, 0].imshow(PIL.ImageOps.invert(Image.fromarray(rgb_img1)))

        axes[0, 1].set_title('search window source')
        axes[0, 1].imshow(PIL.ImageOps.invert(Image.fromarray(cv2.cvtColor(search_window_source, cv2.COLOR_GRAY2RGB))))

        axes[0, 2].set_title('patch source')
        axes[0, 2].imshow(PIL.ImageOps.invert(Image.fromarray(cv2.cvtColor(patch_source, cv2.COLOR_GRAY2RGB))))

        axes[1, 0].set_title('dest image')
        axes[1, 0].imshow(PIL.ImageOps.invert(Image.fromarray(rgb_img2)))

        axes[1, 1].set_title('search window dest')
        axes[1, 1].imshow(PIL.ImageOps.invert(Image.fromarray(cv2.cvtColor(search_window_dest, cv2.COLOR_GRAY2RGB))))

        axes[1, 2].set_title('patch dest')
        axes[1, 2].imshow(PIL.ImageOps.invert(Image.fromarray(cv2.cvtColor(patch_dest, cv2.COLOR_GRAY2RGB))))

        plt.show()
    rgb_img1 = np.swapaxes(rgb_img1, 0, 1)
    rgb_img2 = np.swapaxes(rgb_img2, 0, 1)
    patch_dest = np.swapaxes(patch_dest, 0, 1)
    search_window_source = np.swapaxes(search_window_source, 0, 1)

    return patch_dest,search_window_source,rgb_img1, rgb_img2, points, points_patch_ref, points_patch, dataset1, dataset2

# %%
import matplotlib.cm as cm


def parse_args():
    # init a costum parser which will be added into pl.Trainer parser
    # check documentation: https://pytorch-lightning.readthedocs.io/en/latest/common/trainer.html#trainer-flags
    parser = argparse.ArgumentParser(formatter_class=argparse.ArgumentDefaultsHelpFormatter)
    parser.add_argument(
        'data_cfg_path', type=str, default=".", help='data config path')
    parser.add_argument(
        '--ckpt_path', type=str, default="weights/indoor_large-SEA.ckpt", help='path to the checkpoint')
    parser.add_argument(
        '--dump_dir', type=str, default=None, help="if set, the matching results will be dump to dump_dir")
    parser.add_argument(
        '--profiler_name', type=str, default='inference', help='options: [inference, pytorch], or leave it unset')
    parser.add_argument(
        '--batch_size', type=int, default=1, help='batch_size per gpu')
    parser.add_argument(
        '--num_workers', type=int, default=2)
    parser.add_argument(
        '--thr', type=float, default=None, help='modify the coarse-level matching threshold.')

    parser = pl.Trainer.add_argparse_args(parser)
    return parser.parse_args()




def get_matcher(image_type):

    matcher = LoFTR(config=default_cfg)
    if image_type == 'indoor':
      matcher.load_state_dict(torch.load("weights/indoor_ds.ckpt")['state_dict'])
    elif image_type == 'outdoor':
      matcher.load_state_dict(torch.load("weights/outdoor_ds.ckpt")['state_dict'])
    #model = PL_LoFTR(config, pretrained_ckpt=args.ckpt_path, profiler=profiler)
    return matcher.eval().cuda()
from skimage.measure import ransac


def get_metrics(mkpts0_r, mkpts1_r, points, points_patch, dataset1, dataset2, searching_window_w, searching_window_h,
                patch_w, patch_h, img0_raw, img1_raw, color, verbose=False):
    # Extract x and y coordinates from mkpts0
    x0, y0 = zip(*mkpts0_r)

    # Apply translation to the coordinates
    x_conv, y_conv = get_correspondence_multi(dataset1, dataset2, [x + points[1] for x in x0],
                                              [y + points[0] for y in y0])

    # Convert the translated coordinates back to tuples
    mk0 = list(zip(x_conv, y_conv))

    # Calculate RMSE
    rmse = 0
    for (x1, y1), (x2, y2) in zip(mk0, mkpts1_r):
        y2 -= (searching_window_w / 2) - (patch_w / 2)
        x2 -= (searching_window_h / 2) - (patch_h / 2)
        y2 += points_patch[0]
        x2 += points_patch[1]

        rmse += ((x1 - x2) ** 2 + (y1 - y2) ** 2)

    # Normalize the errors by the number of keypoints
    num_kpts = len(mk0)
    rmse = (rmse / num_kpts) ** (
            1 / 2)  # like in "A Transformer-Based Coarse-to-Fine Wide-Swath SAR Image Registration Method under Weak Texture Conditions"

    return rmse


def cornerness_friendly(gray, points, inliers,random_select=False):
    corners = cv2.goodFeaturesToTrack(gray, 100, 0.01, 15)

    corners = np.int0(corners)
    harris_near = np.zeros((points.shape[0])) + 500

    for match in range(len(points)):
        if inliers[match]:
            arr = [abs(points[match][0] - corner.ravel()[0]) + abs(points[match][1] - corner.ravel()[1]) for corner in
                   corners]
            harris_near[match] = min(arr)
    result= harris_near.argsort()
    if random_select:
      random.shuffle(result)
    return result



def postproces_and_metric(conf, mkpts0, mkpts1, img0, dataset1, dataset2, points, points_patch, searching_window_w,
                          searching_window_h, patch_w, patch_h, rgb_img1, rgb_img2, mconf, threshold_inliers, random_select,
                          save_pdf=True):
    if conf['residual_threshold'] >= 0:
        import time

        # get the start time
        #st = time.time()
        #model, inliers = ransac((mkpts0, mkpts1), AffineTransform, min_samples=conf['min_samples'],
        #                        residual_threshold=conf['residual_threshold'],
        #                        max_trials=conf['max_trials'])
        #et = time.time()

        # get the execution time
        #elapsed_time = et - st
        #print('Ransac Execution time:', elapsed_time, 'seconds inliers:', np.sum(inliers))

        import pymagsac



        #st = time.time()
        order = (mconf).argsort()
        mkpts0 = mkpts0[order]
        mkpts1 = mkpts1[order]
        mconf = mconf[order]

        probabilities = mconf+ min(mconf)
        probabilities  /= max(probabilities )

        correspondences = np.float32([ np.concatenate(( mkpts0[m] , mkpts1[m] )) for m in range(len(mkpts0))]).reshape(-1,4)
        H, inliers = pymagsac.findHomography(
        np.ascontiguousarray(correspondences),
        searching_window_w, searching_window_h, searching_window_w, searching_window_h,
        probabilities = probabilities ,
        sampler = 4,
        #conf = 0.,
        use_magsac_plus_plus = False,
        min_iters=20000,
        sigma_th = float(conf['residual_threshold']))
        #print(mask)
        #et = time.time()

        # get the execution time
        #elapsed_time = et - st
        #print('Magsac++ Execution time:', elapsed_time, 'seconds inliers:',np.sum(mask))

    else:
        inliers = np.zeros_like(range(mkpts0.shape[0]))
        inliers[:] = True


    threshold_inliers = threshold_inliers if threshold_inliers >= 0 else np.sum(inliers)
    n_inliers = np.sum(inliers)

    if inliers is None or n_inliers is None or n_inliers == 0 or (n_inliers < threshold_inliers) :
        conf.update({'rmse': -1, 'inliers': 0 if n_inliers is None else n_inliers})
    else:
        gray = np.array(img0.cpu()).squeeze()
        new_order = cornerness_friendly(gray, mkpts0, inliers,random_select)


        inliers = inliers[new_order]
        print(mkpts0.shape,mkpts0[new_order][inliers][:threshold_inliers].shape)

        rmse = get_metrics(mkpts0[new_order][inliers][:threshold_inliers], mkpts1[new_order][inliers][:threshold_inliers], points,
                           points_patch, dataset1, dataset2,
                           searching_window_w, searching_window_h, patch_w, patch_h, rgb_img1, rgb_img2,
                           mconf[new_order][inliers][:threshold_inliers], verbose=verbose)
        conf.update({'rmse': rmse, 'inliers': n_inliers})

        if save_pdf:
            color = cm.jet(mconf[new_order][inliers][:threshold_inliers], alpha=0.7)
            text = [
                str(conf),
                'Matches: {}'.format(len(mkpts0[new_order][inliers][:threshold_inliers])),
            ]
            abs_m0 = np.array([(x + points[1], y + points[0]) for x, y in mkpts0[new_order][inliers][:threshold_inliers]])
            abs_m1 = np.array([(x - ((searching_window_h / 2) - (patch_h / 2)) + points_patch[1],
                                y - ((searching_window_w / 2) - (patch_w / 2)) + points_patch[0]) for x, y in
                               mkpts1[new_order][inliers][:threshold_inliers]])
            if conf['residual_threshold'] <= 0.5:

                if verbose:
                    fig = make_matching_figure(rgb_img1, rgb_img2, abs_m0, abs_m1, color, abs_m0, abs_m1,
                                               text)
                make_matching_figure(rgb_img1, rgb_img2, abs_m0, abs_m1, color, abs_m0, abs_m1, text,
                                     path="magsacpp"+str(conf['residual_threshold']) +"_rmse_"+str(rmse)+"_inliers_" + str(n_inliers) +".pdf")
    return conf


def predict_and_print(rgb_img1, rgb_img2, matcher, img0_raw, img1_raw, points, points_patch, dataset1, dataset2,
                      searching_window_w, searching_window_h, patch_w, patch_h, configs_ransac ,threshold_inliers,random_select =False):
    '''
        This code performs an image matching task with the given matcher, which takes two raw images and outputs corresponding features. The code first resizes the two raw images to (640, 480) and converts them to torch tensors, normalizing them by dividing each pixel by 255. The two images are then passed to the matcher to get feature matches and confidence scores.
        The code then computes two weighted average points based on the matches, one weighted by the confidence score and the other by a uniform weight. If the number of matches is greater than 0, the code returns the weighted average points and prints them as figures if verbose is set to True. The output figures are saved as "LoFTR-colab-demo.pdf".
I       f there are no matches, the code returns None, None, None, None.
'''

    img0 = torch.from_numpy(img0_raw)[None][None].cuda().to(torch.float) / 255.
    img1 = torch.from_numpy(img1_raw)[None][None].cuda().to(torch.float) / 255.

    batch = {'image0': img0, 'image1': img1}

    # Inference with LoFTR and get prediction
    with torch.no_grad():

        matcher(batch)
        mkpts0 = batch['mkpts0_f'].cpu().numpy()
        mkpts1 = batch['mkpts1_f'].cpu().numpy()
        mconf = batch['mconf'].cpu().numpy()

    if mkpts0.shape[0] > 0:
        return [postproces_and_metric(conf, mkpts0, mkpts1, img0, dataset1, dataset2, points, points_patch,
                                           searching_window_w, searching_window_h, patch_w, patch_h, rgb_img1, rgb_img2,
                                           mconf, threshold_inliers,random_select) for conf in configs_ransac]

    return None

# %%
import os
import numpy as np
import torch

import cv2

loaddirec = "model.pth"
save_path = "./"

device = torch.device("cuda")

# %%
'''
 It takes two images as input, performs image denoising, and then uses a matcher to find the similarity between a patch from the first image and the second image.

The code uses a loop to run the processing for 50 times, for each iteration:

It calls the function get_sample to get the images, points, and datasets.
It denoises the raw images using 3 denoising methods (mean, bilateral, and lee_enhanced). If the denoising didn't produce a result, the code skips to the next iteration.
The code calls the function predict_and_print to get the result of the matcher and to find the similarity between the patch and the search window.
The code uses the result of the matcher to calculate the error in meters between the predicted position and the real position.
The code draws circles on the original full map to show the predicted and real positions.
The code displays the original full map if verbose is set to True.
The code accumulates the error for each iteration and prints the final result, which includes the number of successful predictions and the mean error in meters.
'''


def lee_filter(img, size):
    img_mean = uniform_filter(img, (size, size))
    img_sqr_mean = uniform_filter(img ** 2, (size, size))
    img_variance = img_sqr_mean - img_mean ** 2

    overall_variance = variance(img)

    img_weights = img_variance / (img_variance + overall_variance)
    img_output = img_mean + img_weights * (img - img_mean)
    return img_output


def do_test(matcher_in, path0, path1, size_search=(640, 480), size_patch=(int(180 * 1.333333), int(180)),threshold_inliers=25,
            configs_ransac=None, verbose=True,random_select=False):
    patch_dest,search_window_source, rgb_img1, rgb_img2, points, points_patch_ref, points_patch, dataset1, dataset2 = get_sample(path0, path1,
                                                                                                size_search, size_patch,
                                                                                                verbose=verbose)
    if rgb_img1 is None:
        return None

    import skimage.measure

    results = predict_and_print(rgb_img1, rgb_img2, matcher_in, search_window_source, patch_dest, points, points_patch,
                                dataset1, dataset2, size_search[0], size_search[1], size_patch[0], size_patch[1]
                                , configs_ransac,threshold_inliers,random_select
                               )

    entropy = skimage.measure.shannon_entropy(patch_dest)

    return results, entropy


def get_list():
    path_of_the_directory = './data/paired_sentinel/'
    paths = []
    for filename in os.listdir(path_of_the_directory):
        f = os.path.join(path_of_the_directory, filename)
        if not os.path.isfile(f):
            lst = os.listdir(f)
            if len(lst) > 1:
                paths.append((os.path.join(path_of_the_directory, filename, lst[0]),
                              os.path.join(path_of_the_directory, filename, lst[1])))
    return paths

# %%
matcher_in = get_matcher("outdoor")
verbose = False
random.seed(9)
count_yes = 0
test_for_each_pair = 1
configs_ransac = [{'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0},
                  {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000},
                  {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000},
                  {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000},
                  {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000},
                  {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000}]
paths = get_list()

metrics = [{'rmse': 0, 'inliers': 0, 'accepted_match': 0} for conf in range(len(configs_ransac))]

for path0, path1 in paths:
    for x in range(test_for_each_pair):
        p0, p1 =  (path0, path1) if random.randint(0, 1) else (path0, path1)

        results, entropy = do_test(matcher_in, path0, path1, size_search=(640 + 240, 480 + 240),
                                                     size_patch=(int(180 * 1.333333) * 2, int(180) * 2),
                                                     verbose=verbose,
                                                     configs_ransac=configs_ransac,threshold_inliers=25,random_select=False)


        if results is not None:

            for i in range(len(results)):
                if results[i]['rmse'] >= 0:


                    metrics[i]['rmse'] += results[i]['rmse']
                    metrics[i]['inliers'] += results[i]['inliers']
                    metrics[i]['accepted_match'] += 1
                print(results[i])
                #print(metrics[i])

            count_yes += 1

data = []
for i in range(len(metrics)):
    if metrics[i]['accepted_match'] >0:
        metrics[i]['rmse'] /= metrics[i]['accepted_match']
        metrics[i]['inliers'] /= metrics[i]['accepted_match']
    else:
        metrics[i]['rmse']=0
        metrics[i]['inliers']=0

    configs_ransac[i]['rmse'] = metrics[i]['rmse']
    configs_ransac[i]['inliers'] = metrics[i]['inliers']
    configs_ransac[i]['Accepted_match'] = metrics[i]['accepted_match']
    configs_ransac[i]['total_match'] = test_for_each_pair * len(paths)
    data.append(configs_ransac[i])
    #print("Configuration:",configs_ransac[i-1]," Metrics:",metrics[i], " Accepted_match:", metrics[i]['accepted_match'] ,"/", test_for_each_pair*len(paths))

import pandas as pd

df = pd.DataFrame.from_dict(data)

print(df)

df.to_excel('players.xlsx')
# Out:
# (2036, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 86.60821828771059, 'inliers': 2036}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 10}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 21}
#
# (1988, 2) (25, 2)
# (1988, 2) (25, 2)
# (1988, 2) (25, 2)
# (1988, 2) (25, 2)
# (1988, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 2.700784481849149, 'inliers': 1988}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 17}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 1.9658607591977306, 'inliers': 116}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': 2.1757837975053067, 'inliers': 395}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': 2.0976888645534078, 'inliers': 465}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 2.2572738158436656, 'inliers': 486}
#
# (1971, 2) (25, 2)
# (1971, 2) (25, 2)
# (1971, 2) (25, 2)
# (1971, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 210.3821598343824, 'inliers': 1971}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 12}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': 114.01714236861322, 'inliers': 32}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': 2.402753810217899, 'inliers': 100}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 3.5149383294096275, 'inliers': 142}
#
# (2060, 2) (25, 2)
# (2060, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 207.09350315681337, 'inliers': 2060}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 8}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 212.32579810026394, 'inliers': 27}
#
# (1930, 2) (25, 2)
# (1930, 2) (25, 2)
# (1930, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 309.4005165067408, 'inliers': 1930}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 8}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 18}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': 3.665781415918891, 'inliers': 55}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 2.4998784669322007, 'inliers': 80}
#
# (1990, 2) (25, 2)
# (1990, 2) (25, 2)
# (1990, 2) (25, 2)
# (1990, 2) (25, 2)
# (1990, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 110.86446112433707, 'inliers': 1990}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 2.1181534826947477, 'inliers': 53}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': 2.012657360485358, 'inliers': 133}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': 2.069735336609094, 'inliers': 192}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 2.9385537060759512, 'inliers': 235}
#
# (1939, 2) (25, 2)
# (1939, 2) (25, 2)
# (1939, 2) (25, 2)
# (1939, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 136.30372697743672, 'inliers': 1939}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 18}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': 4.20359774444098, 'inliers': 43}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': 4.426299461872682, 'inliers': 80}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 6.0166453106115805, 'inliers': 130}
#
# (2006, 2) (25, 2)
# (2006, 2) (25, 2)
# (2006, 2) (25, 2)
# (2006, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 10.965837801196932, 'inliers': 2006}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 14}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': 5.603374675299837, 'inliers': 48}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': 3.8906569460099236, 'inliers': 106}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 3.777765233153254, 'inliers': 182}
#
# (1950, 2) (25, 2)
# (1950, 2) (25, 2)
# (1950, 2) (25, 2)
# (1950, 2) (25, 2)
# (1950, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 1.6726450686880605, 'inliers': 1950}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 1.7599137570931453, 'inliers': 32}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': 1.820015255194904, 'inliers': 80}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': 2.100885157080899, 'inliers': 200}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 2.0709008841660683, 'inliers': 275}
#
# (1879, 2) (25, 2)
# (1879, 2) (25, 2)
# (1879, 2) (25, 2)
# (1879, 2) (25, 2)
# (1879, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 101.56364197443071, 'inliers': 1879}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 8}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 2.8529028078551466, 'inliers': 33}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': 3.868318068789528, 'inliers': 91}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': 3.734379196335468, 'inliers': 214}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 3.9273721043251544, 'inliers': 256}
#
# (1893, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 124.44394942638954, 'inliers': 1893}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 9}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 11}
#
# (1947, 2) (25, 2)
# (1947, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 57.94696660862919, 'inliers': 1947}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 11}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 14}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 6.942684581431696, 'inliers': 46}
#
# (1922, 2) (25, 2)
# (1922, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 150.57544534801312, 'inliers': 1922}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 9}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 12}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 243.79422764150183, 'inliers': 33}
#
# (2007, 2) (25, 2)
# (2007, 2) (25, 2)
# (2007, 2) (25, 2)
# (2007, 2) (25, 2)
# (2007, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 1.0428597692681534, 'inliers': 2007}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 19}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 0.917053885217513, 'inliers': 186}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': 1.3982286533186126, 'inliers': 522}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': 1.6203570384040205, 'inliers': 620}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 1.60356689360711, 'inliers': 638}
#
# (1997, 2) (25, 2)
# (1997, 2) (25, 2)
# (1997, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 161.68342575220754, 'inliers': 1997}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 9}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 23}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': 110.84161236009302, 'inliers': 45}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 121.18784460339141, 'inliers': 71}
#
# (1944, 2) (25, 2)
# (1944, 2) (25, 2)
# (1944, 2) (25, 2)
# (1944, 2) (25, 2)
# (1944, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 110.84823530172397, 'inliers': 1944}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 13}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 2.182519571370121, 'inliers': 75}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': 2.728677186299178, 'inliers': 204}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': 2.881022077976749, 'inliers': 256}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 3.1352143392723284, 'inliers': 279}
#
# (1896, 2) (25, 2)
# (1896, 2) (25, 2)
# (1896, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 2.892844930291678, 'inliers': 1896}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 8}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 11}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': 13.65740366851684, 'inliers': 33}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 6.179677186160397, 'inliers': 48}
#
# (1968, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 210.56571742361905, 'inliers': 1968}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 11}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 19}
#
# (1959, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 236.10799569783018, 'inliers': 1959}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 10}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 13}
#
# (2028, 2) (25, 2)
# (2028, 2) (25, 2)
# (2028, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 175.23410600213697, 'inliers': 2028}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 8}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 18}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': 113.15322266910509, 'inliers': 33}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 121.11464276379414, 'inliers': 65}
#
# (1948, 2) (25, 2)
# (1948, 2) (25, 2)
# (1948, 2) (25, 2)
# (1948, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 104.10855796290979, 'inliers': 1948}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 10}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': 27.539284898821705, 'inliers': 27}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': 27.59273195188067, 'inliers': 44}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 46.486525560496034, 'inliers': 55}
#
# (1933, 2) (25, 2)
# (1933, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 123.62670220245516, 'inliers': 1933}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 15}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 356.51086244170466, 'inliers': 25}
#
# (1980, 2) (25, 2)
# (1980, 2) (25, 2)
# (1980, 2) (25, 2)
# (1980, 2) (25, 2)
# (1980, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 505.89191734115786, 'inliers': 1980}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 12}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 4.555831374711402, 'inliers': 71}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': 6.124456041097121, 'inliers': 239}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': 6.140142614370136, 'inliers': 288}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 3.3720303883469036, 'inliers': 295}
#
# (1941, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 202.17243778750031, 'inliers': 1941}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 10}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 10}
#
# (1985, 2) (25, 2)
# (1985, 2) (25, 2)
# (1985, 2) (25, 2)
# (1985, 2) (25, 2)
# (1985, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 146.4132590814965, 'inliers': 1985}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 8}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 2.492919171536525, 'inliers': 59}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': 2.645326145120943, 'inliers': 195}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': 2.818168622705621, 'inliers': 332}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 2.979343676149467, 'inliers': 464}
#
# (2035, 2) (25, 2)
# (2035, 2) (25, 2)
# (2035, 2) (25, 2)
# (2035, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 1.45383809939211, 'inliers': 2035}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 14}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': 3.2138896364397618, 'inliers': 37}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': 2.0910562393730863, 'inliers': 58}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 4.442175678386256, 'inliers': 101}
#
# (1976, 2) (25, 2)
# (1976, 2) (25, 2)
# (1976, 2) (25, 2)
# (1976, 2) (25, 2)
# (1976, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 180.15250336350402, 'inliers': 1976}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 11}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 3.67100213184983, 'inliers': 83}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': 3.80992171517585, 'inliers': 209}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': 3.767824257845362, 'inliers': 249}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 4.097406911032393, 'inliers': 299}
#
# (1771, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 7.549434915622411, 'inliers': 1771}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 9}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 14}
#
# (2054, 2) (25, 2)
# (2054, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 35.92640020513223, 'inliers': 2054}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 8}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 11}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 17}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 246.97287981117546, 'inliers': 33}
#
# (1870, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 336.3816509132083, 'inliers': 1870}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 15}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 21}
#
# (1892, 2) (25, 2)
# (1892, 2) (25, 2)
# (1892, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 6.5359670799556335, 'inliers': 1892}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 8}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': 52.27601586841368, 'inliers': 32}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 64.49014706535719, 'inliers': 43}
#
# (1991, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 158.35385393882987, 'inliers': 1991}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 4}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 8}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 13}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 23}
#
# (2016, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 357.3002752832168, 'inliers': 2016}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 9}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 13}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 17}
#
# (1939, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 420.4919277603474, 'inliers': 1939}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 9}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 12}
#
# (2023, 2) (25, 2)
# (2023, 2) (25, 2)
# (2023, 2) (25, 2)
# (2023, 2) (25, 2)
# (2023, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 66.5297624519199, 'inliers': 2023}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 10}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 1.5975602459218374, 'inliers': 51}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': 1.8381926823076054, 'inliers': 150}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': 2.3729242241171544, 'inliers': 255}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 3.2452127753097884, 'inliers': 347}
#
# (1887, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 74.03295846043106, 'inliers': 1887}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 12}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 14}
#
# (2079, 2) (25, 2)
# (2079, 2) (25, 2)
# (2079, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 33.43087551550796, 'inliers': 2079}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 11}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 17}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': 32.190561989005424, 'inliers': 31}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 60.478825571753525, 'inliers': 47}
#
# (1940, 2) (25, 2)
# (1940, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 268.50743870713626, 'inliers': 1940}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 13}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 24}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 131.77185877724673, 'inliers': 35}
#
# (2064, 2) (25, 2)
# (2064, 2) (25, 2)
# (2064, 2) (25, 2)
# (2064, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 27.70365705319744, 'inliers': 2064}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 8}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 18}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': 4.678639216099243, 'inliers': 69}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': 4.760053986023441, 'inliers': 134}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 4.939097134855416, 'inliers': 216}
#
# (1946, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 308.91733121235313, 'inliers': 1946}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 16}
#
# (2068, 2) (25, 2)
# (2068, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 169.43894772913296, 'inliers': 2068}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 8}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 11}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 5.763389565408546, 'inliers': 37}
#
# (1967, 2) (25, 2)
# (1967, 2) (25, 2)
# (1967, 2) (25, 2)
# (1967, 2) (25, 2)
# (1967, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 34.5387948313828, 'inliers': 1967}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 8}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 1.598212145381175, 'inliers': 31}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': 2.489193825353912, 'inliers': 89}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': 3.743074023017, 'inliers': 146}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 4.294787020624009, 'inliers': 247}
#
# (1959, 2) (25, 2)
# (1959, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 196.97574701706068, 'inliers': 1959}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 4}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 8}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 16}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 28.519680019710563, 'inliers': 28}
#
# (1950, 2) (25, 2)
# (1950, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 8.52052112589236, 'inliers': 1950}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 4}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 15}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 29.372984689820704, 'inliers': 35}
#
# (1972, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 269.6268150966483, 'inliers': 1972}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 8}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 17}
#
# (2062, 2) (25, 2)
# (2062, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 145.06509386605134, 'inliers': 2062}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 14}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 14}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 57.409842719334904, 'inliers': 30}
#
# (2027, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 161.1044830352676, 'inliers': 2027}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 9}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 14}
#
# (1958, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 312.8494110537432, 'inliers': 1958}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 4}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 8}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 13}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 20}
#
# (2025, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 100.12133595385896, 'inliers': 2025}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 8}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 14}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 19}
#
# (1998, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 281.0860399781101, 'inliers': 1998}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 0}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 11}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 18}
#
# (1930, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 230.59285221290878, 'inliers': 1930}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 8}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 11}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 12}
#
# (1890, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 368.0839358696029, 'inliers': 1890}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 3}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 11}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 15}
#
# (1776, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 238.087231577837, 'inliers': 1776}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 16}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 24}
#
# (1805, 2) (25, 2)
# (1805, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 206.45467864852705, 'inliers': 1805}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 8}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 10}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 102.77661082150125, 'inliers': 28}
#
# (1991, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 65.9530271186017, 'inliers': 1991}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 9}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 13}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 21}
#
# (1898, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 436.7039041893633, 'inliers': 1898}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 8}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 10}
#
# (1972, 2) (25, 2)
# (1972, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 212.35990320215362, 'inliers': 1972}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 12}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 19}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 182.208427446209, 'inliers': 50}
#
# (1810, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 360.5068804698064, 'inliers': 1810}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 9}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 14}
#
# (1970, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 150.74708420187784, 'inliers': 1970}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 4}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 8}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 17}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 23}
#
# (2090, 2) (25, 2)
# (2090, 2) (25, 2)
# (2090, 2) (25, 2)
# (2090, 2) (25, 2)
# (2090, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 15.701982744298688, 'inliers': 2090}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 15}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 2.6113533940052025, 'inliers': 129}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': 2.678351582618834, 'inliers': 450}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': 2.8310363879341027, 'inliers': 598}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 3.120280155064445, 'inliers': 655}
#
# (2028, 2) (25, 2)
# (2028, 2) (25, 2)
# (2028, 2) (25, 2)
# (2028, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 68.96848040015678, 'inliers': 2028}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 19}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': 3.3778905329278133, 'inliers': 73}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': 3.257004304624514, 'inliers': 123}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 3.406645561007351, 'inliers': 184}
#
# (1903, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 653.4679695231099, 'inliers': 1903}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 4}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 15}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 19}
#
# (1917, 2) (25, 2)
# (1917, 2) (25, 2)
# (1917, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 41.67665362726635, 'inliers': 1917}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 9}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 14}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': 6.533313235819003, 'inliers': 41}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 10.417037876992193, 'inliers': 63}
#
# (1992, 2) (25, 2)
# (1992, 2) (25, 2)
# (1992, 2) (25, 2)
# (1992, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 643.3562262564759, 'inliers': 1992}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 4}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': 52.560587907151195, 'inliers': 29}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': 1.7408165174006547, 'inliers': 44}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 4.400576164141125, 'inliers': 71}
#
# (1938, 2) (25, 2)
# (1938, 2) (25, 2)
# (1938, 2) (25, 2)
# (1938, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 15.924606843501772, 'inliers': 1938}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 4}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 9}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': 5.493673216741373, 'inliers': 27}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': 5.533709527685892, 'inliers': 72}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 5.349511372988863, 'inliers': 121}
#
# (1919, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 263.8886283937127, 'inliers': 1919}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 17}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 19}
#
# (1891, 2) (25, 2)
# (1891, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 344.7000454747678, 'inliers': 1891}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 4}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 18}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 28.323452727377035, 'inliers': 29}
#
# (2046, 2) (25, 2)
# (2046, 2) (25, 2)
# (2046, 2) (25, 2)
# (2046, 2) (25, 2)
# (2046, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 100.46672450754471, 'inliers': 2046}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 2.7788594975381384, 'inliers': 44}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': 3.3451685038288406, 'inliers': 168}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': 3.9103578671688504, 'inliers': 257}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 3.8953540106351197, 'inliers': 329}
#
# (1850, 2) (25, 2)
# (1850, 2) (25, 2)
# (1850, 2) (25, 2)
# (1850, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 284.9277529639313, 'inliers': 1850}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 12}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': 4.895754315337618, 'inliers': 53}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': 4.515063631128931, 'inliers': 115}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 4.9414750566469845, 'inliers': 168}
#
# (1820, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 382.6658571597512, 'inliers': 1820}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 9}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 12}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 17}
#
# (1738, 2) (25, 2)
# (1738, 2) (25, 2)
# (1738, 2) (25, 2)
# (1738, 2) (25, 2)
# (1738, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 4.330307043156018, 'inliers': 1738}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 9}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': 3.2506902645599136, 'inliers': 49}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': 3.816029168936529, 'inliers': 160}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': 3.689582867915882, 'inliers': 260}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 3.659403801286215, 'inliers': 339}
#
# (2095, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 32.53761431721669, 'inliers': 2095}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 10}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 24}
#
# (1911, 2) (25, 2)
# (1911, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 3.7339051332115707, 'inliers': 1911}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 4}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 7}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 9}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 20}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 138.55049899780363, 'inliers': 33}
#
# (1999, 2) (25, 2)
# (1999, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 390.6981187236581, 'inliers': 1999}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 5}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 8}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 8}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': 166.31887986843998, 'inliers': 29}
#
# (1930, 2) (25, 2)
# {'min_samples': 0, 'residual_threshold': -1, 'max_trials': 0, 'rmse': 137.91282865304078, 'inliers': 1930}
# {'min_samples': 4, 'residual_threshold': 0.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 4}
# {'min_samples': 4, 'residual_threshold': 1, 'max_trials': 10000, 'rmse': -1, 'inliers': 6}
# {'min_samples': 4, 'residual_threshold': 1.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 8}
# {'min_samples': 4, 'residual_threshold': 2, 'max_trials': 10000, 'rmse': -1, 'inliers': 9}
# {'min_samples': 4, 'residual_threshold': 2.5, 'max_trials': 10000, 'rmse': -1, 'inliers': 19}
#    min_samples  residual_threshold  max_trials        rmse      inliers  \
# 0            0                -1.0           0  174.775362  1955.666667
# 1            4                 0.5       10000    0.000000     0.000000
# 2            4                 1.0       10000    2.453774    72.285714
# 3            4                 1.5       10000   11.097256   146.791667
# 4            4                 2.0       10000   14.074362   176.709677
# 5            4                 2.5       10000   53.387004   161.500000
#
#    Accepted_match  total_match
# 0              75           75
# 1               0           75
# 2              14           75
# 3              24           75
# 4              31           75
# 5              46           75

# %%
import pandas as pd

df = pd.DataFrame.from_dict(data)

print(df)

df.to_excel('players.xlsx')
# Out:
#    min_samples  residual_threshold  max_trials        rmse      inliers  \
# 0            0                -1.0           0  174.775362  1955.666667
# 1            4                 0.5       10000    0.000000     0.000000
# 2            4                 1.0       10000    2.453774    72.285714
# 3            4                 1.5       10000   11.097256   146.791667
# 4            4                 2.0       10000   14.074362   176.709677
# 5            4                 2.5       10000   53.387004   161.500000
#
#    Accepted_match  total_match
# 0              75           75
# 1               0           75
# 2              14           75
# 3              24           75
# 4              31           75
# 5              46           75
